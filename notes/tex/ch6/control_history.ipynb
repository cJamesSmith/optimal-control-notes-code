# %%
from IPython.display import Video

# %%
Video(filename="/home/xwc/Downloads/test.mp4")
# Out:
# <video src="/home/xwc/Downloads/test.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
